# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.19.2-cp37-cp37m-macosx_10_13_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 2.5 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 35.2 MB/s eta 0:00:01
# Requirement already satisfied: networkx>=2.2 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (1.21.2)
# Requirement already satisfied: packaging>=20.0 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (2.17.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/surekha/opt/anaconda3/envs/DAAN570/lib/python3.7/site-packages (from packaging>=20.0->scikit-image) (3.0.4)
# Installing collected packages: tifffile, scikit-image
# Successfully installed scikit-image-0.19.2 tifffile-2021.11.2

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage
from sklearn.cluster import KMeans

#################################
#####Preprocessing the image####
#################################

# dividing by 255 to bring the pixel values between 0 and 1
pic = plt.imread('eiffel.jpeg')/255  

pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
print(pic_n.shape)

#################################
#########Kmeans Clustering#######
#################################
kmeans = KMeans(n_clusters=5, random_state=0).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
#plt.imshow(cluster_pic)

f, axarr = plt.subplots(2,figsize=(15,15))
axarr[0].imshow(pic)
axarr[1].imshow(cluster_pic)
# Out:
# (333500, 3)

# %%
#################################
#####Preprocessing the image####
#################################

# dividing by 255 to bring the pixel values between 0 and 1
pic = plt.imread('pencils.jpeg')/255  

pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
print(pic_n.shape)

#################################
#########Kmeans Clustering#######
#################################
kmeans = KMeans(n_clusters=5, random_state=0).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
#plt.imshow(cluster_pic)

f, axarr = plt.subplots(2,figsize=(15,15))
axarr[0].imshow(pic)
axarr[1].imshow(cluster_pic)
# Out:
# (39220, 3)

# %%
#################################
#####Preprocessing the image####
#################################

# dividing by 255 to bring the pixel values between 0 and 1
pic = plt.imread('kids_crossing_road.jpeg')/255  

pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
print(pic_n.shape)

#################################
#########Kmeans Clustering#######
#################################
kmeans = KMeans(n_clusters=5, random_state=0).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
#plt.imshow(cluster_pic)

f, axarr = plt.subplots(2,figsize=(15,15))
axarr[0].imshow(pic)
axarr[1].imshow(cluster_pic)
# Out:
# (372000, 3)
